# %% [markdown]
# # Equivalent Layer technique for estimating magnetization direction of a magnetized source

# %% [markdown]
# #### Importing libraries

# %%
% matplotlib inline

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime
import timeit
from scipy.optimize import nnls
from fatiando.gridder import regular
from fatiando.utils import ang2vec, vec2ang
from fatiando.mesher import Sphere, PointGrid,Prism
from fatiando.gravmag import sphere,prism
from fatiando.constants import CM, T2NT, G, SI2MGAL
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
notebook_name = 'regular_EQL_magdirection_RM.ipynb'

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../../mypackage'
sys.path.append(dir_modules)

# %%
import auxiliary_functions as fc

# %% [markdown]
# #### Loading properties of the model

# %%
with open('data/model_sphere.pickle') as f:
        model_sphere = pickle.load(f)

# %% [markdown]
# #### Loading properties grid

# %%
with open('data/regular_grid.pickle') as f:
        reg_grid = pickle.load(f)

# %% [markdown]
# #### Loading data

# %%
with open('data/data_set.pickle') as f:
        data = pickle.load(f)

# %% [markdown]
# #### Open a dictionary

# %%
results_RM_reg = dict()

# %% [markdown]
# ### Saving files

# %%
saved_files = []

# %% [markdown]
# ## Observation area

# %%
print 'Area limits: \n x_max = %.1f m \n x_min = %.1f m \n y_max = %.1f m \n y_min = %.1f m' % (reg_grid['area'][1], 
                                                                                                reg_grid['area'][0],
                                                                                                reg_grid['area'][3],
                                                                                                reg_grid['area'][2])
# Out:
# Area limits:
#  x_max = 6000.0 m
#  x_min = -6000.0 m
#  y_max = 6000.0 m
#  y_min = -6000.0 m

# %% [markdown]
# ### reg_grid survey information

# %%
print 'Shape : (%.0f,%.0f)'% reg_grid['shape'] 
print 'Number of data: %.1f' % reg_grid['N']
print 'dx: %.1f m' % reg_grid['dx']
print 'dy: %.1f m ' % reg_grid['dy']
# Out:
# Shape : (20,20)
# Number of data: 400.0
# dx: 631.6 m
# dy: 631.6 m

# %% [markdown]
# ## Properties of the model

# %% [markdown]
# ### Main field

# %%
inc_gf,dec_gf = model_sphere['main_field']

# %%
print'Main field inclination: %.1f degree' % inc_gf
print'Main field declination: %.1f degree' % dec_gf
# Out:
# Main field inclination: 40.0 degree
# Main field declination: 45.0 degree

# %% [markdown]
# ### Magnetization direction

# %%
print 'Intensity: %.1f A/m' % model_sphere['m_R']
print 'Inclination: %.1f degree' % model_sphere['inc_R']
print 'Declination: %.1f degree' % model_sphere['dec_R']
# Out:
# Intensity: 3.0 A/m
# Inclination: 30.0 degree
# Declination: 20.0 degree

# %%
inc_R,dec_R = model_sphere['inc_R'],model_sphere['dec_R']

# %% [markdown]
# ## Generating the layer with my function

# %%
h = 600.

# %% [markdown]
# #### Generating a layer

# %%
shape_layer = (reg_grid['shape'][0],reg_grid['shape'][1])

# %%
xs,ys,zs = regular(reg_grid['area'],shape_layer,h)

# %% [markdown]
# ## Non-negative Least Squares Method for estimating a positive layer

# %%
M = xs.size
N = reg_grid['x'].size

# %%
mu = 1e-7

# %%
I = np.identity(M)

# %%
G = fc.sensitivity_mag(reg_grid['x'],reg_grid['y'],reg_grid['z'],
                       xs,ys,zs,inc_gf,dec_gf,inc_R,dec_R)

# %%
null = np.zeros(M)

# %%
do = np.hstack([data['tfa_obs_sphere_RM_reg'],null])

# %%
GI = np.vstack([G,mu*I])

# %%
start_time = timeit.default_timer()

# %%
m_pos,_ = nnls(GI,do)

# %%
elapsed = timeit.default_timer() - start_time

# %%
print elapsed
# Out:
# 0.19903087616

# %%
tf_pred_pos = fc.tfa_layer(reg_grid['x'],reg_grid['y'],reg_grid['z'],
                           xs,ys,zs,inc_gf,dec_gf,m_pos,inc_R,dec_R)

# %% [markdown]
# ### Calculating residual

# %%
r_pos = data['tfa_obs_sphere_RM_reg'] - tf_pred_pos

# %% [markdown]
# #### Parameters for normalized histogram

# %%
r_norm,r_mean,r_std = fc.residual(data['tfa_obs_sphere_RM_reg'],tf_pred_pos)

# %%
print r_mean
# Out:
# 0.218200297072

# %% [markdown]
# ## Comparison between the Model and the Layer with posivity

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(18,18), tight_layout=True)

ranges = saturation_factor*np.abs([data['tfa_obs_sphere_RM_reg'].max(), 
                                   data['tfa_obs_sphere_RM_reg'].min(),
                                   tf_pred_pos.max(), tf_pred_pos.min()]).max()

r_ranges = saturation_factor*np.abs([r_pos.max(), r_pos.min()]).max()


plt.subplot(2,2,1)
plt.contourf(reg_grid['y'].reshape(reg_grid['shape']),
             reg_grid['x'].reshape(reg_grid['shape']), 
             data['tfa_obs_sphere_RM_reg'].reshape(reg_grid['shape']),
             20, cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font) 
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('(a) TFA (model_RM) ', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=15)

plt.subplot(2,2,2)
plt.contourf(reg_grid['y'].reshape(reg_grid['shape']),
             reg_grid['x'].reshape(reg_grid['shape']),
             tf_pred_pos.reshape(reg_grid['shape']),
             20, cmap='viridis',  vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('(b) TFA (Layer)', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=15)

plt.subplot(2,2,3)
plt.contourf(reg_grid['y'].reshape(reg_grid['shape']),
             reg_grid['x'].reshape(reg_grid['shape']),
             r_pos.reshape(reg_grid['shape']), 
             20, cmap='viridis',  vmin=-r_ranges, vmax=r_ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('(c) Residual map', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=15)


plt.subplot(2,2,4)
plt.xlabel('$\mu$ = %.3f | $\sigma$ = %.3f nT' % (r_mean, r_std),
           fontsize = bottom_font)
nbins = int((np.max(r_norm - np.min(r_norm))))
plt.hist(r_norm,bins=nbins,normed=True)
plt.ylim(0.,1.)
plt.xlim(-10., 10.)
plt.title('(d) Normalized Histogram',fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

file_name = 'figs/regular/noisy_data_fitting_NNLS_magRM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')

plt.show()
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### Magnetic moment within the Layer with positivity constraint

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(9,9), tight_layout=True)

plt.contourf(ys.reshape(shape_layer),xs.reshape(shape_layer), 
             m_pos.reshape(shape_layer),20, cmap='viridis')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('$A.m^2$',size=15)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Magnetic moment (layer)', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

file_name = 'figs/regular/noisy_magnetic_moment_positive_NNLS_magIM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')

plt.show()

# %% [markdown]
# ### Levenberg-Marquardt with NNLS for positive magnetic moments

# %%
i_pos = 1500

# %%
it_max = 30

# %%
it_marq = 15

# %%
lamb = 10.
dlamb = 100.

# %%
eps_e = 1e-4
eps_i = 1e-4

# %%
mu_LM = 1e5

# %%
m_LM,inc_est,dec_est,phi,imax,pest,incs,decs = fc.levenberg_marquardt_NNLS(
    data['tfa_obs_sphere_RM_reg'],reg_grid['x'],reg_grid['y'],
    reg_grid['z'],xs,ys,zs,inc_gf,dec_gf,-10.,-10.,lamb,dlamb,i_pos,it_max,
    it_marq,eps_e,eps_i,mu_LM)
# Out:
# i = 0
# -0.833479953759 0.656258831593
# 0.267164533452
# i = 1
# 6.89673915518 6.02698850553
# 0.496873283771
# i = 2
# 10.8411050108 8.16736227263
# 0.39863254559
# i = 3
# 13.365279303 9.59932931743
# 0.254140605603
# i = 4
# 15.2342365226 10.6781609237
# 0.186253732601
# i = 5
# 16.7154981069 11.5244575172
# 0.146866045588
# i = 6
# 17.9390878608 12.212416013
# 0.121209529922
# i = 7
# 18.9836171191 12.7933498707
# 0.104207361386
# i = 8
# 19.8901540459 13.2949004526
# 0.0909164130534
# i = 9
# 20.6854257428 13.7348399619
# 0.0797636208152
# i = 10
# 21.3905271905 14.1272144312
# 0.0705030084084
# i = 11
# 22.020012034 14.4811962607
# 0.0624152521635
# i = 12
# 22.5842961906 14.8036878292
# 0.0550825273962
# i = 13
# 23.0940782836 15.0997408167
# 0.0488713700397
# i = 14
# 23.5568469446 15.373027433
# 0.0433904852051
# i = 15
# 23.9796901963 15.6273653457
# 0.0387445186409
# i = 16
# 24.3670063177 15.8639120417
# 0.0345099706468
# i = 17
# 24.7232752451 16.0844356139
# 0.030795623394
# i = 18
# 25.0523579781 16.290794503
# 0.0275565971342
# i = 19
# 25.3572763601 16.4839836309
# 0.0246833033306
# i = 20
# 25.6405303415 16.66528547
# 0.0221250624452
# i = 21
# 25.9039886078 16.8356674435
# 0.0198013564562
# i = 22
# 26.1482635939 16.9947920944
# 0.0175308055963
# i = 23
# 26.3745116587 17.1442821095
# 0.0154407939847
# i = 24
# 26.5845819332 17.2852561167
# 0.013626807337
# i = 25
# 26.7804660162 17.4191037616
# 0.0121028526166
# i = 26
# 26.963818714 17.5462882389
# 0.0108052823208
# i = 27
# 27.1355894692 17.6671187675
# 0.00964355124753
# i = 28
# 27.2968559087 17.7820426793
# 0.00862895571382
# i = 29
# 27.44870631 17.8915684412
# 0.00775485427213
# i = 30
# 27.5927143827 17.9960010208
# 0.00705679400273
# i = 31
# 27.729226792 18.095411345
# 0.0064080464265
# i = 32
# 27.8589224646 18.189612811
# 0.00583539868406
# i = 33
# 27.981694477 18.2789142888
# 0.0052721524575
# i = 34
# 28.0977247891 18.3633085479
# 0.00474271224097
# i = 35
# 28.2072341871 18.4429182194
# 0.00425091904959
# i = 36
# 28.3103934429 18.5178225061
# 0.0037923415588
# i = 37
# 28.407487399 18.5883199991
# 0.00337540164167
# i = 38
# 28.4990180154 18.6547212699
# 0.00301194862025
# i = 39
# 28.5861596866 18.7173229751
# 0.00273850023066
# i = 40
# 28.6692783503 18.7762603637
# 0.00249751294889
# i = 41
# 28.7485388837 18.8317234533
# 0.00227577762231
# i = 42
# 28.8236693607 18.8839125128
# 0.00204900050807
# i = 43
# 28.8948751927 18.9334535699
# 0.00184524380252
# i = 44
# 28.9623053783 18.9805087653
# 0.0016586889253
# i = 45
# 29.0260473212 19.0252003869
# 0.00148557685918
# i = 46
# 29.0863295131 19.0676445033
# 0.0013314177564
# i = 47
# 29.1433743785 19.1079929479
# 0.00119455185561
# i = 48
# 29.1973066266 19.1463442033
# 0.00106966053564
# i = 49
# 29.2482640063 19.1827561314
# 0.000956403537761
# i = 50
# 29.2963850728 19.2173260186
# 0.000854132789816
# i = 51
# 29.3417967715 19.25014877
# 0.000761706129221
# i = 52
# 29.3846226369 19.2813114301
# 0.000678322019637
# i = 53
# 29.4249845523 19.3108972081
# 0.000603282546411
# i = 54
# 29.4629995858 19.3389867629
# 0.000535839510749
# i = 55
# 29.4987803084 19.3656580164
# 0.000475305864734
# i = 56
# 29.5324445193 19.3909792825
# 0.000421263220965
# i = 57
# 29.5641861361 19.4149959263
# 0.000374847413224
# i = 58
# 29.5940803901 19.4377944486
# 0.000332839713776
# i = 59
# 29.6222051213 19.4594487675
# 0.00029496624028
# i = 60
# 29.6486539446 19.4800175473
# 0.000261195714527
# i = 61
# 29.6735170255 19.4995566187
# 0.000231125304215
# i = 62
# 29.6968787509 19.5181206453
# 0.000204349161633
# i = 63
# 29.7188206585 19.5357611759
# 0.000180543552004
# i = 64
# 29.7394226512 19.5525259078
# 0.000159427287566
# i = 65
# 29.7587610012 19.5684601474
# 0.00014071456529
# i = 66
# 29.7769083909 19.5836069096
# 0.000124146321398
# i = 67
# 29.7939339757 19.5980070164
# 0.000109488470521
# i = 68
# 29.7939339757 19.5980070164
# 0.0

# %% [markdown]
# ### Visualization of the convergence

# %%
phi = (np.array(phi)/reg_grid['x'].size)

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(9,9), tight_layout=True)

plt.figure(figsize=(10, 10))
plt.plot(phi, 'b--')
plt.plot(phi, 'b.')

plt.title('Convergence analysis', fontsize=title_font)
plt.xlabel('iteration', fontsize = title_font)
plt.ylabel('$\phi$', fontsize = title_font)
plt.tick_params(axis='both', which='major', labelsize=15)

file_name = 'figs/regular/convergence_LM_NNLS_magRM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')


plt.show()

# %% [markdown]
# ### Estimated magnetization direction

# %%
print (inc_est,dec_est)
# Out:
# (29.79393397572824, 19.598007016406321)

# %%
print (inc_R,dec_R)
# Out:
# (30.0, 20.0)

# %% [markdown]
# ### Comparison between observed data and predicted data

# %%
pred = fc.tfa_layer(reg_grid['x'],reg_grid['y'],reg_grid['z'],
                    xs,ys,zs,inc_gf,dec_gf,m_LM,inc_est,dec_est)

# %%
res = pred - data['tfa_obs_sphere_RM_reg']

# %%
r_norm,r_mean,r_std = fc.residual(data['tfa_obs_sphere_RM_reg'],pred)

# %%
title_font = 18
bottom_font = 15
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(15,15), tight_layout=True)

ranges = saturation_factor*np.abs([data['tfa_obs_sphere_RM_reg'].max(), 
                                   data['tfa_obs_sphere_RM_reg'].min(),
                                   pred.max(), pred.min()]).max()
res_ranges = np.max(np.abs(res))

plt.subplot(2,2,1)
plt.contourf(reg_grid['y'].reshape(reg_grid['shape']),
             reg_grid['x'].reshape(reg_grid['shape']), 
             data['tfa_obs_sphere_RM_reg'].reshape(reg_grid['shape']),
             20, cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('(a) TFA (model_RM)',fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

plt.subplot(2,2,2)
plt.contourf(reg_grid['y'].reshape(reg_grid['shape']),
             reg_grid['x'].reshape(reg_grid['shape']),
             pred.reshape(reg_grid['shape']),
             20, cmap='viridis',  vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('(b) TFA (Layer)', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

plt.subplot(2,2,3)
plt.contourf(reg_grid['y'].reshape(reg_grid['shape']),
             reg_grid['x'].reshape(reg_grid['shape']),
             res.reshape(reg_grid['shape']), 
             20, cmap='viridis',  vmin=-res_ranges, vmax=res_ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('(c) Residual map', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)


plt.subplot(2,2,4)
plt.xlabel('$\mu$ = %.3f | $\sigma$ = %.3f nT' % (r_mean, r_std),
           fontsize = bottom_font)
nbins = int((np.max(r_norm - np.min(r_norm))))
plt.hist(r_norm,bins=nbins,normed=True)
plt.ylim(0.,1.)
plt.xlim(-10., 10.)
plt.title('(d) Normalized Histogram',fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

file_name = 'figs/regular/data_fitting_LM_NNLS_magRM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')


plt.show()

# %% [markdown]
# ### Estimated magnetic moment within the layer

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(9,9), tight_layout=True)

plt.contourf(ys.reshape(shape_layer),xs.reshape(shape_layer), 
             m_LM.reshape(shape_layer), 20, cmap='viridis')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('$A.m^2$',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Magnetic moment (layer)', fontsize=title_font)

file_name = 'figs/regular/magnetic_moment_positive_LM_NNLS_magRM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')


plt.show()

# %% [markdown]
# ### Reduction to the pole

# %%
G_rtp = fc.sensitivity_mag(reg_grid['x'],reg_grid['y'],reg_grid['z'],
                       xs,ys,zs,90.,0.,90.,0.)

# %%
tfa_rtp = np.dot(G_rtp,m_LM)

# %% [markdown]
# #### Visualization of a reduction to the pole

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(9,9), tight_layout=True)

plt.contourf(reg_grid['y'].reshape(reg_grid['shape']), 
             reg_grid['x'].reshape(reg_grid['shape']),
             tfa_rtp.reshape(reg_grid['shape']), 
             20, cmap='inferno')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (RTP)', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

file_name = 'figs/regular/RTP_reg_grid_magRM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')

plt.show()

# %% [markdown]
# # Visualization of the RTP and Magnetic moment over the layer

# %%
title_font = 18
bottom_font = 15
plt.close('all')
plt.figure(figsize=(20,10), tight_layout=True)

plt.subplot(1,2,1)
plt.tricontourf(ys,xs,m_LM,20,cmap='viridis')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('$A.m^2$',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Magnetic moment (layer)', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

plt.subplot(1,2,2)
plt.tricontourf(reg_grid['y'],reg_grid['x'], tfa_rtp, 20, cmap='inferno')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT',size=bottom_font)
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (RTP)', fontsize=title_font)
plt.tick_params(axis='both', which='major', labelsize=12)

file_name = 'figs/regular/RTP_moment_LM_NNLS_RM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')

plt.show()

# %% [markdown]
# ### Results

# %% [markdown]
# #### Generating .pickle file

# %%
#now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
#data_set['metadata'] = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)

# %%
file_name = 'data/results_IM_reg.pickle'
with open(file_name, 'w') as f:
    pickle.dump(results_RM_reg, f)
    
saved_files.append(file_name)

# %% [markdown]
# ### Saved files

# %%
with open('reports/report_%s.md' % notebook_name[:st.index(notebook_name, '.')], 'w') as q:
    q.write('# Saved files \n')
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
    q.write('\n\n'+header+'\n\n')
    for i, sf in enumerate(saved_files):
        print '%d  %s' % (i+1,sf)
        q.write('*  `%s` \n' % (sf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-9cd88a3b5c00> in <module>()
# ----> 1 with open('reports/report_%s.md' % notebook_name[:st.index(notebook_name, '.')], 'w') as q:
#       2     q.write('# Saved files \n')
#       3     now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
#       4     header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
#       5     q.write('\n\n'+header+'\n\n')
#
# NameError: name 'st' is not defined
