# %% [markdown]
# # Equivalent Layer with positivity: convergence and parameter analysis

# %% [markdown]
# #### Importing libraries

# %%
% matplotlib inline

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime
import timeit
from scipy.optimize import nnls
from fatiando.gridder import regular
from fatiando.utils import ang2vec, vec2ang
from fatiando.mesher import Sphere, PointGrid,Prism
from fatiando.gravmag import sphere,prism
from fatiando.constants import CM, T2NT, G, SI2MGAL
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
notebook_name = 'EQL_convergence_parameters.ipynb'

# %% [markdown]
# ### Gray background figures

# %%
plt.style.use('grayscale')

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../'
sys.path.append(dir_modules)

# %%
import eql_functions as func

# %%
import auxiliary_functions as fc

# %% [markdown]
# #### Loading properties of the model

# %%
with open('data/model_sphere_remanent.pickle') as f:
        model_sphere_remanent = pickle.load(f)

# %% [markdown]
# #### Loading properties grid

# %%
with open('data/regular_grid.pickle') as f:
        regular_grid = pickle.load(f)

# %% [markdown]
# #### Loading data

# %%
with open('data/data_set.pickle') as f:
        data = pickle.load(f)

# %% [markdown]
# ### Saving files

# %%
saved_files = []

# %% [markdown]
# ## Observation area

# %%
print 'Area limits: \n x_max = %.1f m \n x_min = %.1f m \n y_max = %.1f m \n y_min = %.1f m' % (regular_grid['area'][1], 
                                                                                                regular_grid['area'][0],
                                                                                                regular_grid['area'][3],
                                                                                                regular_grid['area'][2])
# Out:
# Area limits:
#  x_max = 10000.0 m
#  x_min = -10000.0 m
#  y_max = 10000.0 m
#  y_min = -10000.0 m

# %% [markdown]
# ### Regular grid information

# %%
print 'Shape : (%.0f,%.0f)'% regular_grid['shape'] 
print 'Number of data: %.1f' % regular_grid['N']
print 'dx: %.1f m' % regular_grid['dx']
print 'dy: %.1f m ' % regular_grid['dy']
# Out:
# Shape : (30,30)
# Number of data: 900.0
# dx: 689.7 m
# dy: 689.7 m

# %% [markdown]
# ## Properties of the model

# %% [markdown]
# ### Dimension and coordinate of the center

# %%
print 'Properties Sphere:\n xc = %.1f m \n yc = %.1f m \n zc = %.1f m \n radius = %.1f m ' %  (model_sphere_remanent['xc'],
                                                                                               model_sphere_remanent['yc'],
                                                                                               model_sphere_remanent['zc'],
                                                                                               model_sphere_remanent['radius'])
# Out:
# Properties Sphere:
#  xc = 0.0 m
#  yc = 0.0 m
#  zc = 2000.0 m
#  radius = 1500.0 m

# %% [markdown]
# ### Main field

# %%
inc_gf,dec_gf = model_sphere_remanent['main_field']

# %%
print'Main field inclination: %.1f degree' % inc_gf
print'Main field declination: %.1f degree' % dec_gf
# Out:
# Main field inclination: 40.0 degree
# Main field declination: 45.0 degree

# %% [markdown]
# ### Magnetization direction

# %%
print 'Intensity: %.1f A/m' % model_sphere_remanent['m_R']
print 'Inclination: %.1f degree' % model_sphere_remanent['inc_R']
print 'Declination: %.1f degree' % model_sphere_remanent['dec_R']
# Out:
# Intensity: 20.0 A/m
# Inclination: 60.0 degree
# Declination: 10.0 degree

# %%
inc_R,dec_R = model_sphere_remanent['inc_R'],model_sphere_remanent['dec_R']

# %% [markdown]
# ## Generating a layer

# %%
h = 2000.

# %%
shape_layer = (25,25)

# %%
xs,ys,zs = regular(regular_grid['area'],shape_layer,h)

# %% [markdown]
# ## Data misfit analysis for different inc's and dec's

# %%
N_inc = 10

# %%
incs = np.linspace(-90.,90.,num=N_inc)

# %%
N_dec = 10

# %%
decs = np.linspace(0.,180.,num=N_dec)

# %%
Incs, Decs = np.meshgrid(incs,decs)

# %%
phi = []
p_est = []
for i,d in zip(Incs.ravel(),Decs.ravel()):
    G = fc.sensitivity_mag(regular_grid['x'],regular_grid['y'],regular_grid['z'],
                       xs,ys,zs,inc_gf,dec_gf,i,d)
    m,_ = nnls(G,data['tfa_obs_sphere_RM_reg'])
    tf_pred = fc.tfa_layer(regular_grid['x'],regular_grid['y'],regular_grid['z'],
                           xs,ys,zs,inc_gf,dec_gf,m,i,d)
    r = data['tfa_obs_sphere_RM_reg'] - tf_pred
    misfit = np.sum(r*r)
    phi.append(misfit)
    p_est.append(m)

# %%
phi = (np.array(phi)/regular_grid['x'].size).reshape(N_inc,N_dec)

# %% [markdown]
# ### Data misfit map

# %%
i_est= [-60.0, -47.761435584914324, -24.888866865641859, 0.022848418394937564, 7.5554092061259244, 10.849613405602007, 13.207789609209749, 15.024482182653399, 16.53712723788696, 17.871967211802012, 19.094322335548572, 20.227825561720024, 21.289901660578305, 22.291283965519263, 23.2464764513775, 24.159676415877858, 25.024347431059383, 25.851957141305057, 26.6364546330101, 27.385407839085506, 28.110512699075972, 28.807595668100916, 29.481895042650969, 30.138050970251165, 30.776864859644, 31.403364254321769, 32.019799547446283, 32.62666441249845, 33.227105199581523, 33.824459268728724, 34.419681214565031, 35.015772804487817, 35.615599641742392, 36.222804708556382, 36.838440726380689, 37.464308697375714, 38.103087988685296, 38.754651030106942, 39.42024259137402, 40.101332223910894, 40.798352640664802, 41.511658811867058, 42.240525975658542, 42.985365895835358, 43.745626734839774, 44.519840869104513, 45.303875800153307, 46.095171425051788, 46.889682698880478, 47.682840462068299, 48.469252461691617, 49.242510314763862, 49.996375295048779, 50.725046484796756, 51.42365489576077, 52.087938497074077, 52.714409177969308, 53.300952242242332, 53.846951039437677, 54.352958798366998, 54.820307000319154, 55.250844135303275, 55.646956915052854, 56.01106279201786, 56.345362339145815, 56.652256631321237, 56.934155225766595, 57.193143226392841, 57.43104341696958, 57.64941943058674, 57.849903411281346, 58.033928805504075, 58.202688619242515, 58.357414131745792, 58.499231941683796, 58.629186661114588, 58.74822534359226, 58.857240826008038, 58.957042606168599, 59.048378674272001, 59.131935802375828, 59.208347018949304, 59.27816856360603, 59.341923092438911, 59.400120367246082, 59.453231006570483, 59.501695765124587, 59.545988182402645, 59.586443754892024, 59.62337658913399, 59.657078671935388, 59.687820435834553, 59.715852051227557, 59.741404129566902, 59.764689190437423, 59.785902801485506, 59.805224678691125, 59.822819782138332, 59.838839373036279, 59.853422022296108, 59.86669457009765, 59.878773033544718, 59.889763458232395, 59.899762679702221, 59.908859182262617, 59.917133711519128, 59.92465992279196, 59.931504980297966, 59.937730109903121, 59.943391108269836, 59.948538811178892, 59.953219523807071, 59.957475415610432, 59.961344882372629, 59.964862877864391, 59.968061217427739, 59.970968855667415, 59.9736121402997, 59.976015044074373, 59.978199376556745, 59.98018497743066, 59.981989892861179, 59.983630536343924, 59.985121835355606, 59.986477365018175, 59.987709469894533, 59.988829374942021, 59.989847286565833, 59.990772484638022, 59.
9999999917517677, 9.9999999925037617, 9.9999999931871688, 9.9999999938082684, 9.9999999943727449, 9.9999999948857585, 9.9999999953520309, 9.999999995775779, 9.999999996160911, 9.9999999965109261, 9.9999999968290432, 9.9999999971181239, 9.9999999973808862, 9.9999999976196996, 9.9999999978367207, 9.9999999980339283, 9.9999999982132124, 9.9999999983761576, 9.9999999985241956, 9.9999999986587227, 9.9999999987809911, 9.9999999988920845, 9.9999999989930703, 9.9999999990848973, 9.9999999991682795, 9.9999999992441246, 9.9999999993130491, 9.9999999993756621, 9.9999999994326352, 9.9999999994844284, 9.999999999531445, 9.9999999995741806, 9.9999999996130011, 9.9999999996482796, 9.9999999996803997, 9.9999999997094999, 9.9999999997359872, 9.9999999997600764, 9.9999999997819256, 9.9999999998017959, 9.9999999998198845, 9.9999999998363158, 9.9999999998512354, 9.9999999998647748, 9.9999999998770583, 9.9999999998882814, 9.9999999998984546, 9.9999999999077609, 9.9999999999161933, 9.9999999999238529, 9.9999999999307896, 9.9999999999370637, 9.999999999942828, 9.9999999999480327, 9.9999999999527667, 9.999999999957085, 9.9999999999609681, 9.9999999999645564, 9.9999999999677929, 9.9999999999707452, 9.9999999999734008, 9.9999999999758611, 9.9999999999780762, 9.9999999999800409, 9.9999999999818137, 9.9999999999834461, 9.999999999984956, 9.9999999999863274, 9.9999999999875495, 9.9999999999887219, 9.9999999999897788, 9.9999999999907434, 9.9999999999916103, 9.9999999999924096, 9.9999999999931202, 9.9999999999937614, 9.9999999999943476, 9.9999999999948699, 9.9999999999953531, 9.9999999999957616, 9.9999999999961418, 9.9999999999965361, 9.9999999999968914, 9.9999999999972111, 9.9999999999975184, 9.9999999999977742, 9.9999999999980229, 9.9999999999982201, 9.9999999999983906, 9.999999999998554, 9.9999999999986979, 9.9999999999988365, 9.9999999999989644, 9.9999999999990834, 9.9999999999991722, 9.9999999999992504, 9.9999999999993179, 9.9999999999993729, 9.9999999999994369, 9.9999999999994937, 9.9999999999995417, 9.9999999999995772, 9.9999999999996216, 9.9999999999996607, 9.9999999999996767, 9.9999999999996998, 9.9999999999997122, 9.9999999999997318, 9.9999999999997513, 9.9999999999997637, 9.9999999999997833, 9.9999999999997797, 9.9999999999997939, 9.9999999999998028, 9.9999999999998082, 9.9999999999998117, 9.9999999999998384, 9.9999999999998543, 9.9999999999998384, 9.9999999999998455, 9.9999999999998437, 9.9999999999998437, 9.9999999999998472, 9.9999999999998366, 9.9999999999998312, 9.9999999999998259, 9.9999999999998117, 9.9999999999998099, 9.9999999999998295, 9.9999999999998384, 9.9999999999998384

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(10,10), tight_layout=True)

ranges = saturation_factor*np.abs([phi.max(), phi.min()]).max()

plt.contourf(Incs,Decs,phi,40, cmap='hsv',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
levels = plt.contour(Incs,Decs,phi,40,linecolor='b',vmin=-ranges, vmax=ranges)
plt.clabel(levels, inline=1, fontsize=10)
plt.plot(inc_R,dec_R,'b*',markersize=15)
plt.plot(i_est,d_est,'w.',markersize=15)
plt.xlabel('Inc (degree)', fontsize = title_font)
plt.ylabel('Dec (degree)', fontsize = title_font)
plt.title('Data misfit map ', fontsize=title_font)

file_name = 'figs/data_misfit_-90_90'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
