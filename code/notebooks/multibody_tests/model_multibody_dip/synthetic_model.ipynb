# %% [markdown]
# # Synthetic Model

# %% [markdown]
# Notebook to generate a set of models.

# %% [markdown]
# #### Import libraries

# %%
from IPython.display import Markdown as md
from IPython.display import display as dp
import string as st
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime

from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
from fatiando.utils import ang2vec, vec2ang
from fatiando.mesher import Sphere, Prism, PolygonalPrism
from fatiando.gravmag import sphere, prism, polyprism
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
notebook_name = 'synthetic_model.ipynb'

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../../../mypackage'
sys.path.append(dir_modules)

# %%
import auxiliary_functions as func

# %% [markdown]
# #### Loading 2D grid properties

# %%
with open('data/regular_grid.pickle') as f:
        regular = pickle.load(f)

# %%
with open('data/airborne_survey.pickle') as f:
        airborne = pickle.load(f)

# %% [markdown]
# #### List of saved files

# %%
saved_files = []

# %% [markdown]
# ### Observation area

# %%
print 'Area limits: \n x_max = %.1f m \n x_min = %.1f m \n y_max = %.1f m \n y_min = %.1f m' % (regular['area'][1], regular['area'][0],regular['area'][3],regular['area'][2])
# Out:
# Area limits:
#  x_max = 6000.0 m
#  x_min = -6000.0 m
#  y_max = 6000.0 m
#  y_min = -6000.0 m

# %% [markdown]
# ## Regional Field

# %%
inc_gf , dec_gf = (-20.,-20.)

# %% [markdown]
# ## Create a model w/ the presence of Remanence Magnetization

# %%
model_multi = dict()

# %% [markdown]
# ### main field

# %%
model_multi['main_field'] = (inc_gf,dec_gf)

# %% [markdown]
# ### Magnetization direction of bodies

# %%
model_multi['m_R'] = 15.
model_multi['inc_R'] = -45.
model_multi['dec_R'] = 30.

mag_tot_R = ang2vec(model_multi['m_R'],
                  model_multi['inc_R'],
                  model_multi['dec_R'])

model_multi['magnetization'] = mag_tot_R

# %% [markdown]
# #### Setting bounds of a polygonal cross-section

# %%
% matplotlib notebook
fig = plt.figure(figsize=(9,9), tight_layout=True)

ax = fig.add_subplot(111)
ax.set_title('Click on figure to set any point')
ax.axis([regular['y'].min(), regular['y'].max(), regular['x'].min(), regular['x'].max()])
ax.set_ylabel('x(m)')
ax.set_xlabel('y(m)')


line, = ax.plot([], [])
line.figure.canvas.draw()
x = []
y = []
plotx = []
ploty = []
def pick(event):
    if event.inaxes != ax.axes:
        return 'It must be any point over de area '
    x.append(event.ydata)
    y.append(event.xdata)
    plotx.append(event.xdata)
    ploty.append(event.ydata)
    line.set_color('r')
    line.set_marker('o')
    line.set_linestyle('')
    line.set_data(plotx,ploty)
    line.figure.canvas.draw()

line.figure.canvas.mpl_connect('button_press_event', pick)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print x
# Out:
# []

# %%
print y
# Out:
# []

# %% [markdown]
# ## Magnetization prisms

# %%
model_multi['m_Rp'] = 5.
model_multi['inc_R'] = -45.
model_multi['dec_R'] = 30.

mag_tot_Rp = ang2vec(model_multi['m_Rp'],
                  model_multi['inc_R'],
                  model_multi['dec_R'])

model_multi['magnetization_p'] = mag_tot_Rp

# %% [markdown]
# ### Vertices of a Polygonal prism-1

# %%
model_multi['x1_verts'] = [-120.86173387456893, 217.88504245497916, -139.68099922621059, -1005.3672054017161, -2002.788269038715, -3019.0285980273529, -3884.7148042028603, -4204.6423151807649, -3809.4377427962945, -2360.3543107199021, -1494.6681045443956, -666.62042907216983, -120.86173387456893]
model_multi['y1_verts'] = [-1475.5336403581159, -822.01437309183802, -227.90594830431655, -386.33486158098731, -623.97823149599935, -604.17461733641267, -227.90594830431655, -1020.0505146876794, -1594.3553253156206, -1574.5517111560348, -1297.3011129218594, -1396.3191837197774, -1475.5336403581159]

# %%
model_multi['z1_top'] = 350.
model_multi['z1_bottom'] = 2850.

# %%
model_multi['verts1'] = zip(model_multi['x1_verts'],
                                   model_multi['y1_verts'] )

# %% [markdown]
# ### Vertices of a polygonal prism-3

# %%
model_multi['x2_verts'] = [2860.7375129736383, 2841.9182476220003, 2258.5210217211124, 2277.3402870727577, 2860.7375129736383]

model_multi['y2_verts'] = [1992.4086951532709, 2784.5532615366383, 2784.5532615366346, 1992.4086951532745, 1992.4086951532709 ]

# %%
model_multi['z2_top'] = 450.
model_multi['z2_bottom'] = 1050.

# %%
model_multi['verts2'] = zip(model_multi['x2_verts'],
                                   model_multi['y2_verts'] )

# %% [markdown]
# ### Creating a polyprism model

# %%
model_multi['polygons'] = [PolygonalPrism(model_multi['verts1'],
                                              model_multi['z1_top'],
                                              model_multi['z1_bottom'],
                                              {'magnetization':mag_tot_Rp}),
                            PolygonalPrism(model_multi['verts2'],
                                              model_multi['z2_top'],
                                              model_multi['z2_bottom'],
                                              {'magnetization':mag_tot_Rp})]

# %% [markdown]
# ## Magnetization spheres

# %%
model_multi['m_Rs'] = 10.
model_multi['inc_R'] = -45.
model_multi['dec_R'] = 30.

mag_tot_Rs = ang2vec(model_multi['m_Rs'],
                  model_multi['inc_R'],
                  model_multi['dec_R'])

model_multi['magnetization_s'] = mag_tot_Rs

# %% [markdown]
# ### Sphere-1

# %%
model_multi['xc1'] = 1800.
model_multi['yc1'] = -1800.
model_multi['zc1'] = 1000.
model_multi['radius1'] = 500.

# %% [markdown]
# ### Sphere-2

# %%
model_multi['xc2'] = 800.
model_multi['yc2'] = 800.
model_multi['zc2'] = 1000.
model_multi['radius2'] = 500.

# %% [markdown]
# ### Creating a spheres model

# %%
model_multi['spheres'] = [Sphere(model_multi['xc1'],
                                         model_multi['yc1'],
                                         model_multi['zc1'],
                                         model_multi['radius1'],
                                         {'magnetization':mag_tot_Rs}),
                            Sphere(model_multi['xc2'],
                                         model_multi['yc2'],
                                         model_multi['zc2'],
                                         model_multi['radius2'],
                                         {'magnetization':mag_tot_Rs})]

# %%
theta = np.linspace(0, 2 * np.pi, 100)

# %% [markdown]
# ## Magnetization dip model

# %%
model_multi['m_Rd'] = 15.
model_multi['inc_R'] = -45.
model_multi['dec_R'] = 30.

mag_tot_Rd = ang2vec(model_multi['m_Rd'],
                  model_multi['inc_R'],
                  model_multi['dec_R'])

model_multi['magnetization_d'] = mag_tot_Rd

# %% [markdown]
# ## Dipping body model

# %%
model_multi['verts_x_max'] = -1000.
model_multi['verts_x_min'] = -3000.
model_multi['y_max'] = 2800.
model_multi['y_min'] = 1800
model_multi['z_min'] = 450.
model_multi['z_max'] = 1600.
model_multi['z_thick'] = 200.
model_multi['N_prism'] = 41

# %%
model_multi['verts_x'] = np.linspace(model_multi['verts_x_min'],
                                   model_multi['verts_x_max'],
                                   model_multi['N_prism'])

# %%
model_multi['x_mins'] = []
model_multi['x_maxs'] = []
for i in range(len(model_multi['verts_x'])-1):
    model_multi['x_mins'].append(model_multi['verts_x'][i])
    model_multi['x_maxs'].append(model_multi['verts_x'][i+1])

# %%
model_multi['x_mins'] = np.array(model_multi['x_mins'])
model_multi['x_maxs'] = np.array(model_multi['x_maxs'])

# %%
model_multi['z_tops'] = np.linspace(model_multi['z_min'],
                                  model_multi['z_max'], 
                                  model_multi['N_prism']-1)
model_multi['z_bottoms'] = np.linspace(model_multi['z_min'] + model_multi['z_thick'],
                                     model_multi['z_max'] + model_multi['z_thick'], 
                                     model_multi['N_prism']-1)

# %%
model_multi['x_verts_dip'] = [model_multi['verts_x_max'],model_multi['verts_x_min'],model_multi['verts_x_min'],model_multi['verts_x_max'],model_multi['verts_x_max']]
model_multi['y_verts_dip'] = [model_multi['y_max'],model_multi['y_max'],model_multi['y_min'],model_multi['y_min'],model_multi['y_max']]

# %% [markdown]
# ### Creating model

# %%
model_multi['dip'] = []
for i in range(model_multi['N_prism']-1):
    model_multi['dip'].append(Prism(model_multi['x_mins'][i],model_multi['x_maxs'][i],
                           model_multi['y_min'],model_multi['y_max'],
                           model_multi['z_tops'][i],model_multi['z_bottoms'][i],
                           {'magnetization':mag_tot_Rd}))

# %% [markdown]
# #### Generating .pickle file

# %%
now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
model_multi['metadata'] = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)

# %%
file_name = 'data/model_multi.pickle'
with open(file_name, 'w') as f:
    pickle.dump(model_multi, f)
    
saved_files.append(file_name)

# %% [markdown]
# ## Visualization of model projection

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(9,9), tight_layout=True)

plt.title('Model projection',fontsize=title_font)

plt.plot(model_multi['y1_verts'],model_multi['x1_verts'], 
         color='k',linestyle='-',linewidth=2)
plt.plot(model_multi['y2_verts'],model_multi['x2_verts'], 
         color='k',linestyle='-',linewidth=2)

plt.plot(model_multi['y_verts_dip'],model_multi['x_verts_dip'], 
         color='k',linestyle='-',linewidth=2)


plt.plot(model_multi['radius1']*np.sin(theta)+ model_multi['yc1'] ,
         model_multi['radius1']*np.cos(theta)+ model_multi['xc1'], 
         color='k',linestyle='-',linewidth=2)

plt.plot(model_multi['radius2']*np.sin(theta)+ model_multi['yc2'] ,
         model_multi['radius2']*np.cos(theta)+ model_multi['xc2'], 
         color='k',linestyle='-',linewidth=2)

plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.ylim(np.min(regular['x']),np.max(regular['x']))
plt.xlim(np.min(regular['y']),np.max(regular['y']))
plt.tick_params(labelsize=15)

file_name = 'figs/model_projection'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=200)
saved_files.append(file_name+'.eps')


plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# #### Saved files

# %%
with open('reports/report_%s.md' % notebook_name[:st.index(notebook_name, '.')], 'w') as q:
    q.write('# Saved files \n')
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
    q.write('\n\n'+header+'\n\n')
    for i, sf in enumerate(saved_files):
        print '%d  %s' % (i+1,sf)
        q.write('*  `%s` \n' % (sf))
# Out:
# 1  data/model_multi.pickle
# 2  figs/model_projection.png
# 3  figs/model_projection.eps
