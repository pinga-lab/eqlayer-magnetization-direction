# %% [markdown]
# # Classical Equivalent Layer Magnetic

# %% [markdown]
# #### Importing libraries

# %%
% matplotlib inline

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime
import string as st
from fatiando.gridder import regular
from fatiando.utils import ang2vec, vec2ang
from fatiando.mesher import Sphere, PointGrid,Prism
from fatiando.gravmag import sphere,prism
from fatiando.constants import CM, T2NT, G, SI2MGAL

# %%
notebook_name = 'regular_EQL_classical_mag.ipynb'

# %% [markdown]
# #### Black background figures

# %%
plt.style.use('grayscale')

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../'
sys.path.append(dir_modules)

# %%
import auxiliary_functions as fc

# %%
import eql_functions as func

# %% [markdown]
# #### Loading properties of the model

# %%
with open('data/model_poly_remanent.pickle') as f:
        model_poly_remanent = pickle.load(f)

# %% [markdown]
# #### Loading properties grid

# %%
with open('data/regular_grid.pickle') as f:
        regular_grid = pickle.load(f)

# %% [markdown]
# #### Loading data

# %%
with open('data/data_set.pickle') as f:
        data = pickle.load(f)

# %% [markdown]
# ### Saving files

# %%
saved_files = []

# %% [markdown]
# ## Observation area

# %%
print 'Area limits: \n x_max = %.1f m \n x_min = %.1f m \n y_max = %.1f m \n y_min = %.1f m' % (regular_grid['area'][1], 
                                                                                                regular_grid['area'][0],
                                                                                                regular_grid['area'][3],
                                                                                                regular_grid['area'][2])
# Out:
# Area limits:
#  x_max = 10000.0 m
#  x_min = -10000.0 m
#  y_max = 10000.0 m
#  y_min = -10000.0 m

# %% [markdown]
# ### Regular grid information

# %%
print 'Shape : (%.0f,%.0f)'% regular_grid['shape'] 
print 'Number of data: %.1f' % regular_grid['N']
print 'dx: %.1f m' % regular_grid['dx']
print 'dy: %.1f m ' % regular_grid['dy']
print 'Height: %.1f m' % regular_grid['z_obs']
# Out:
# Shape : (30,30)
# Number of data: 900.0
# dx: 689.7 m
# dy: 689.7 m
# Height: 0.0 m

# %% [markdown]
# ## Properties of the model

# %% [markdown]
# ### Top and bottom of the polyprism

# %%
print 'Properties of a polyprism :\n Top = %.1f m \n Bottom = %.1f m \n Vertices = %.f ' %  (model_poly_remanent['z_top'],
                                                                                                model_poly_remanent['z_bottom'],
                                                                                                len(model_poly_remanent['verts']))
# Out:
# Properties of a polyprism :
#  Top = 800.0 m
#  Bottom = 3500.0 m
#  Vertices = 7

# %% [markdown]
# ### Main field

# %%
inc_gf,dec_gf = model_poly_remanent['main_field']

# %%
print'Main field inclination: %.1f degree' % inc_gf
print'Main field declination: %.1f degree' % dec_gf
# Out:
# Main field inclination: 40.0 degree
# Main field declination: 45.0 degree

# %% [markdown]
# ### Magnetization direction

# %% [markdown]
# #### Sphere w/ the presence of a Remanent magnetization

# %%
print 'Intensity: %.1f A/m' % model_poly_remanent['m_R']
print 'Inclination: %.1f degree' % model_poly_remanent['inc_R']
print 'Declination: %.1f degree' % model_poly_remanent['dec_R']
# Out:
# Intensity: 5.0 A/m
# Inclination: 70.0 degree
# Declination: 30.0 degree

# %%
inc_R,dec_R = model_poly_remanent['inc_R'],model_poly_remanent['dec_R']

# %% [markdown]
# ## Generating the layer with my function

# %%
h = 1200.

# %% [markdown]
# #### Generating a layer

# %%
shape_layer = (25,25)

# %%
xs,ys,zs = regular(regular_grid['area'],shape_layer,h)

# %% [markdown]
# ## Calculating Sensitivity Matrix

# %%
G = fc.sensitivity_mag(regular_grid['x'],regular_grid['y'],regular_grid['z'],
                         xs,ys,zs,inc_gf,dec_gf,inc_R,dec_R)

# %% [markdown]
# ## Solving linear System without positivity constraint

# %%
mu = 1e-18

# %%
I = np.identity(xs.size)

# %%
m = np.linalg.solve(np.dot(G.T,G)+mu*I,np.dot(G.T,data['tfa_obs_poly_RM_reg']))

# %%
tf_pred = fc.tfa_layer(regular_grid['x'],regular_grid['y'],regular_grid['z'],
                       xs,ys,zs,inc_gf,dec_gf,m,inc_R,dec_R)

# %% [markdown]
# ### Calculating residual

# %%
r = data['tfa_obs_poly_RM_reg'] - tf_pred

# %% [markdown]
# #### Parameters for normalized histogram

# %%
r_norm,r_mean,r_std = func.residual(data['tfa_obs_poly_RM_reg'],tf_pred)

# %% [markdown]
# ## Comparison between the Model and the Layer

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(19,7), tight_layout=True)

ranges = saturation_factor*np.abs([data['tfa_obs_poly_RM_reg'].max(), 
                                   data['tfa_obs_poly_RM_reg'].min(),
                                   tf_pred.max(), tf_pred.min()]).max()

r_ranges = saturation_factor*np.abs([r.max(), r.min()]).max()

plt.subplot(1,4,1)
plt.contourf(regular_grid['y'].reshape(regular_grid['shape']),
             regular_grid['x'].reshape(regular_grid['shape']), 
             data['tfa_obs_poly_RM_reg'].reshape(regular_grid['shape']),
             20, cmap='RdBu_r',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (RM_reg_grid) ', fontsize=title_font)

plt.subplot(1,4,2)
plt.contourf(regular_grid['y'].reshape(regular_grid['shape']),
             regular_grid['x'].reshape(regular_grid['shape']), 
             tf_pred.reshape(regular_grid['shape']), 20,
             cmap='RdBu_r',  vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (Layer)', fontsize=title_font)

plt.subplot(1,4,3)
plt.contourf(regular_grid['y'].reshape(regular_grid['shape']),
             regular_grid['x'].reshape(regular_grid['shape']), 
             r.reshape(regular_grid['shape']), 20,
             cmap='RdBu_r',  vmin=-r_ranges, vmax=r_ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Residual map', fontsize=title_font)


plt.subplot(1,4,4)
plt.xlabel('$\mu$ = %.3f | $\sigma$ = %.3f nT' % (r_mean, r_std), fontsize = bottom_font)
nbins = int((np.max(r_norm - np.min(r_norm))))
plt.hist(r_norm,bins=nbins,normed=True)
plt.ylim(0.,1.)
plt.xlim(-10., 10.)
plt.title('Normalized Histogram',fontsize=title_font)

file_name = 'figs/regular/noisy_data_fitting_classical_eqlayer'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()
# Out:
# /home/andre/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### Magnetic moment within the layer

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

ranges = saturation_factor*np.abs([m.max(), m.min()]).max()

plt.contourf(ys.reshape(shape_layer),
             xs.reshape(shape_layer),
             m.reshape(shape_layer), 20,
             cmap='RdBu_r',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('$A.m^2$')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Magnetic moment (layer)', fontsize=title_font)
plt.text(6300.,9300.,'Inc = %.1f'% inc_R,family='ubuntu',style='normal')
plt.text(5900.,8800.,'Inc_mf = %.1f'% inc_gf,family='ubuntu',style='normal' )

file_name = 'figs/regular/noisy_magnetic_moment_classical_eqlayer'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Saved files

# %%
with open('reports/report_%s.md' % notebook_name[:st.index(notebook_name, '.')], 'w') as q:
    q.write('# Saved files \n')
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
    q.write('\n\n'+header+'\n\n')
    for i, sf in enumerate(saved_files):
        print '%d  %s' % (i+1,sf)
        q.write('*  `%s` \n' % (sf))
# Out:
# 1  figs/regular/noisy_data_fitting_classical_eqlayer.png
# 2  figs/regular/noisy_magnetic_moment_classical_eqlayer.png
