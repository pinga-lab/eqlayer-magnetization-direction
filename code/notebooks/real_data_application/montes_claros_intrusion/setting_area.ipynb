# %% [markdown]
# # Setting the area for the data according of Lat and Long

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Filename

# %%
filename = 'Mag.XYZ'

# %% [markdown]
# ### Getting informations about the file

# %%
def flight_lines(filename):
    '''
    Get the information about the flight lines of the airborne survey
    
    input
    
    filename: string - String containing the file name.
    
    return
    
    n_lines : integer - number of flight lines
    lines : list - List of strings with the line number
    i_line : list - List with the position of the lines within the file
    '''
    
    f = open(filename)
        
    lines = []
    index = []
    for i,line in enumerate(f):
        if line[:4] == 'Line':
            index.append(i)
            lines.append(line[:14])
        
    f.close()
    return index,lines

# %%
index,line_str = flight_lines(filename)

# %%
print len(index) # posição da linha DO ARQUIVO
# Out:
# 1576

# %%
print line_str[0] # Nome da linhda de VOO
# Out:
# Line  20010

# %% [markdown]
# ### Defining long for lines

# %%
def long_lines(filename,index,long_min,long_max):
    '''
    Get the longitude of lines
    '''
    f=open(filename)
    read_lines =f.readlines()
    
    longi = []
    for i in index:
        longi.append(float(read_lines[i+1][149:159]))
        
    mask = [(lg <= long_max) and (lg >= long_min) for lg in longi]
    index_area = []
    for i,msk in enumerate(mask):
        if msk == True:
            index_area.append(i)
    
    f.close()
    return longi, index_area

# %%
long_max = -51.
long_min = -52.

# %%
lon,i_area = long_lines(filename,index,long_min,long_max) # Valores de longitude das linhas de VOO

# %%
print len(i_area)
# Out:
# 433

# %% [markdown]
# ### Defining columns for the file

# %%
names = ['X','Y','GPSALT','MAGRAW','MAGIGRF','IGRF','LONG','LAT']

# %% [markdown]
# ### Getting the information for the lines

# %%
lon_max = -51.31
lon_min = -51.45

# %%
lat_max = -15.96
lat_min = -16.12

# %%
f = open('data_XYZ_area','w+')
fd = open('data_filtered_XYZ_area_40','w+')
for i in i_area:
    print i
    n = index[i+1] - index[i] - 1
    df = pd.read_csv(filename,usecols=(0,1,3,7,12,13,14,15),na_values= '*',
                     nrows=n,names=names,skiprows=index[i]+1,
                     skipinitialspace=True,delim_whitespace=True)    
    mask = (df['LONG'] <= lon_max) & (df['LONG'] >= lon_min) & (df['LAT'] <= lat_max) & (df['LAT'] >= lat_min)
    data_area = df[mask]
    filtered_data = data_area.iloc[range(0,data_area.shape[0],40),:]
    data_area.to_csv(f,header=None,index=None,sep=' ',mode='w+')
    filtered_data.to_csv(fd,header=None,index=None,sep=' ',mode='w+')
# Out:
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1448
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# 1486
# 1487
# 1488
# 1489
# 1490
# 1491
# 1492
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1504
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1518
# 1519
# 1520
# 1521
# 1522
# 1523
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# 1533
# 1534
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1541
# 1542
# 1543
# 1544
# 1545
# 1546
# 1547
# 1548
# 1549
