# %% [markdown]
# # Equivalent Layer technique for estimating magnetization application for Montes Claros complex of Goias Alkaline Province (GAP)

# %% [markdown]
# #### Importing libraries

# %%
% matplotlib inline

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime
import timeit
import pandas as pd

from scipy.optimize import nnls
from fatiando.gridder import regular
from fatiando.utils import ang2vec, vec2ang
from fatiando.mesher import Sphere, PointGrid,Prism
from fatiando.gravmag import sphere,prism
from fatiando.constants import CM, T2NT, G, SI2MGAL
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
notebook_name = 'MC_intrusion_EQL_magdirection.ipynb'

# %% [markdown]
# ### Gray background figures

# %%
plt.style.use('grayscale')

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../../mypackage'
sys.path.append(dir_modules)

# %%
import auxiliary_functions as fc

# %% [markdown]
# #### Open a dictionary

# %%
data_set = dict()

# %% [markdown]
# #### Saving files

# %%
saved_files = []

# %% [markdown]
# ## Loading real data for Diorama complex

# %% [markdown]
# ### Columns to load and filename

# %%
filename = 'data_filtered_XYZ_area_20'

# %%
names = ['X','Y','GPSALT','MAGRAW','MAGIGRF','IGRF','LONG','LAT']

# %% [markdown]
# ### Real data

# %%
data = pd.read_csv(filename,usecols=(0,1,2,3,4,5,6,7),na_values= '*',names=names,skipinitialspace=True,delim_whitespace=True)

# %% [markdown]
# ## Properties of survey

# %% [markdown]
# ### Total field anomaly

# %%
data_set['tfa_20'] = data.iloc[:,4].get_values()

# %% [markdown]
# #### Observation coordinates

# %%
data_set['x'] = data.iloc[:,1].get_values()

# %%
data_set['y'] = data.iloc[:,0].get_values()

# %%
data_set['height'] = -100.

# %%
data_set['z'] = data_set['height']*np.ones_like(data_set['x'])

# %% [markdown]
# #### Survey information

# %%
data_set['N'] = np.size(data_set['tfa_20'])

# %%
data_set['dx'] = data_set['x'][0] - data_set['x'][1]

# %%
Nx = int(((data_set['x'].max() - data_set['x'].min())/(data_set['dx'])))

# %%
Ny = data_set['N']/Nx

# %%
data_set['dy'] = int(((data_set['y'].max() - data_set['y'].min())/(Ny-1)))

# %%
data_set['shape'] = Nx,Ny

# %%
print 'Shape : (%.0f,%.0f)'% data_set['shape'] 
print 'Number of data: %.1f' % data_set['N']
print 'dx: %.1f m' % data_set['dx']
print 'dy: %.1f m ' % data_set['dy']
# Out:
# Shape : (47,19)
# Number of data: 907.0
# dx: 163.5 m
# dy: 502.0 m

# %% [markdown]
# #### Main field

# %%
inc_gf = -19.5

# %%
dec_gf = -18.5

# %%
data_set['main_field'] = inc_gf,dec_gf

# %%
print'Main field inclination: %.1f degree' % inc_gf
print'Main field declination: %.1f degree' % dec_gf
# Out:
# Main field inclination: -19.5 degree
# Main field declination: -18.5 degree

# %% [markdown]
# ## Real data visualization for Diorama complex

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

ranges = saturation_factor*np.abs([data_set['tfa_20'].max(),data_set['tfa_20'].min()]).max()

plt.tricontourf(data_set['y'],data_set['x'],data_set['tfa_20'],20, cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (Diorama complex) ', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=13)

file_name = 'figs/real_data_diorama_decimated_20'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Generating the layer with my function

# %%
h = 160.

# %% [markdown]
# #### Generating a layer

# %%
xs = data_set['x']

# %%
ys = data_set['y']

# %%
zs = h*np.ones_like(xs)

# %% [markdown]
# ## Non-negative Least Squares Method for estimating a positive layer

# %%
G = fc.sensitivity_mag(data_set['x'],data_set['y'],data_set['z'],
                       xs,ys,zs,inc_gf,dec_gf,-71.,-23.)

# %%
start_time = timeit.default_timer()

# %%
m_pos,_ = nnls(G,data_set['tfa_20'])

# %%
elapsed = timeit.default_timer() - start_time

# %%
print elapsed
# Out:
# 0.655571937561

# %%
tf_pred_pos = fc.tfa_layer(data_set['x'],data_set['y'],data_set['z'],
                           xs,ys,zs,inc_gf,dec_gf,m_pos,-71.,-23.)

# %% [markdown]
# ### Calculating residual

# %%
r_pos = data_set['tfa_20'] - tf_pred_pos

# %% [markdown]
# #### Parameters for normalized histogram

# %%
r_norm,r_mean,r_std = func.residual(data_set['tfa_20'],tf_pred_pos)

# %%
print r_mean
# Out:
# 5.28742037102

# %% [markdown]
# ## Comparison between the Model and the Layer with posivity

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(20,9), tight_layout=True)

ranges = saturation_factor*np.abs([data_set['tfa_20'].max(), 
                                   data_set['tfa_20'].min(),
                                   tf_pred_pos.max(), tf_pred_pos.min()]).max()

r_ranges = saturation_factor*np.abs([r_pos.max(), r_pos.min()]).max()


plt.subplot(1,4,1)
plt.tricontourf(data_set['y'], data_set['x'], data_set['tfa_20'], 20, cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (Obs) ', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=11)

plt.subplot(1,4,2)
plt.tricontourf(data_set['y'],data_set['x'], tf_pred_pos, 20, cmap='viridis',  vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (Layer)', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=11)

plt.subplot(1,4,3)
plt.tricontourf(data_set['y'],data_set['x'], r_pos, 20, cmap='viridis',  vmin=-r_ranges, vmax=r_ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Residual map', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=11)


plt.subplot(1,4,4)
plt.xlabel('$\mu$ = %.3f | $\sigma$ = %.3f nT' % (r_mean, r_std),
           fontsize = bottom_font)
nbins = int((np.max(r_norm - np.min(r_norm))))
plt.hist(r_norm,bins=nbins,normed=True)
plt.ylim(0.,1.)
plt.xlim(-10., 10.)
plt.title('Normalized Histogram',fontsize=title_font)

file_name = 'figs/real_data_NNLS_oliveirajr2015'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()

# %% [markdown]
# ### Magnetic moment within the Layer with positivity constraint

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

ranges = saturation_factor*np.abs([m_pos.max(), m_pos.min()]).max()

plt.tricontourf(ys,xs,m_pos,20,cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('$A.m^2$')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Magnetic moment (layer)', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=13)

file_name = 'figs/magnetic_moment_positive_NNLS_oliveirajr2015'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()

# %% [markdown]
# ### Levenberg-Marquardt with NNLS for positive magnetic moments

# %%
i_pos = 1500

# %%
it_max = 30

# %%
it_marq = 15

# %%
lamb = 10.
dlamb = 100.

# %%
eps = 1e-3

# %%
m_LM,inc_est,dec_est,phi,imax,pest,incs,decs = fc.levenberg_marquardt_NNLS(
    data_set['tfa_20'],data_set['x'],data_set['y'], data_set['z']
    ,xs,ys,zs,inc_gf,dec_gf,-30.,-110.,lamb,dlamb,i_pos,it_max, it_marq,eps)
# Out:
# i = 0
# -33.2168605496 -109.945876317
# 0.321299137551
# i = 1
# -35.5152722575 -110.026920026
# 0.308187958421
# i = 2
# -37.0877033813 -110.106305847
# 0.218520173555
# i = 3
# -38.4023866571 -110.046722935
# 0.188183528944
# i = 4
# -39.7190044012 -109.783289181
# 0.245719968773
# i = 5
# -40.9675844917 -109.373163579
# 0.357122110723
# i = 6
# -41.9420033951 -108.974364334
# 0.385368946657
# i = 7
# -42.6366347793 -108.651469555
# 0.321545630895
# i = 8
# -43.1456351559 -108.396110071
# 0.259373392273
# i = 9
# -43.5309864246 -108.19526339
# 0.208963737123
# i = 10
# -43.8318443614 -108.037634002
# 0.169906095915
# i = 11
# -44.0709888277 -107.915009381
# 0.136697862506
# i = 12
# -44.2661070206 -107.820327881
# 0.1117106814
# i = 13
# -44.4281706648 -107.748221154
# 0.0919067774733
# i = 14
# -44.5654907281 -107.693717946
# 0.0769001706201
# i = 15
# -44.6828228397 -107.654110131
# 0.0643260613166
# i = 16
# -44.784280238 -107.626733833
# 0.0543589279782
# i = 17
# -44.8731780674 -107.609159692
# 0.0466514284766
# i = 18
# -44.9513880738 -107.599955151
# 0.0400780141664
# i = 19
# -45.0208119788 -107.597637339
# 0.0348312533449
# i = 20
# -45.0826808356 -107.601202598
# 0.0304060874052
# i = 21
# -45.1382080126 -107.609705455
# 0.0268398200299
# i = 22
# -45.1887002357 -107.622097915
# 0.0241915621949
# i = 23
# -45.2354112268 -107.637363876
# 0.022394094039
# i = 24
# -45.2796987146 -107.653539372
# 0.0212751658029
# i = 25
# -45.3222696207 -107.670207192
# 0.0206281692234
# i = 26
# -45.3632297167 -107.687322598
# 0.0200217920166
# i = 27
# -45.4026754134 -107.704838358
# 0.0194506165505
# i = 28
# -45.4406951086 -107.72271152
# 0.0189116581376
# i = 29
# -45.4773700433 -107.740902949
# 0.0184022523899
# i = 30
# -45.5127750466 -107.759376921
# -47.6877701097 -111.605844498
# 0.00115987090688
# i = 526
# -47.6886527003 -111.60748432
# 0.00115372537357
# i = 527
# -47.6895324699 -111.609116939
# 0.00114760513452
# i = 528
# -47.6904094301 -111.610742388
# 0.00114151016871
# i = 529
# -47.6912835926 -111.612360702
# 0.00113544045381
# i = 530
# -47.6921549688 -111.613971915
# 0.0011293959668
# i = 531
# -47.6930235701 -111.615576059
# 0.00112337668383
# i = 532
# -47.6938894079 -111.617173169
# 0.00111738258009
# i = 533
# -47.6947524935 -111.618763278
# 0.00111141362987
# i = 534
# -47.6956128381 -111.620346419
# 0.00110546980674
# i = 535
# -47.6964704528 -111.621922625
# 0.00109955108323
# i = 536
# -47.6973253487 -111.623491928
# 0.00109365743116
# i = 537
# -47.6981775368 -111.625054362
# 0.00108778882162
# i = 538
# -47.6990270279 -111.62660996
# 0.00108194522451
# i = 539
# -47.699873833 -111.628158752
# 0.00107612660928
# i = 540
# -47.7007179628 -111.629700773
# 0.00107033294429
# i = 541
# -47.7015594281 -111.631236053
# 0.00106456419733
# i = 542
# -47.7023982394 -111.632764625
# 0.00105882033514
# i = 543
# -47.7032344074 -111.63428652
# 0.00105310132388
# i = 544
# -47.7040679426 -111.635801771
# 0.00104740712879
# i = 545
# -47.7048988554 -111.637310408
# 0.00104173771444
# i = 546
# -47.7057271563 -111.638812463
# 0.00103609304446
# i = 547
# -47.7065528555 -111.640307967
# 0.00103047308186
# i = 548
# -47.7073759633 -111.641796951
# 0.00102487778888
# i = 549
# -47.7081964899 -111.643279446
# 0.00101930712693
# i = 550
# -47.7090144454 -111.644755482
# 0.00101376105671
# i = 551
# -47.70982984 -111.646225091
# 0.00100823953824
# i = 552
# -47.7106426835 -111.647688303
# 0.00100274253077
# i = 553
# -47.7106426835 -111.647688303
# 0.0

# %% [markdown]
# ### Visualization of the convergence

# %%
phi = (np.array(phi)/data_set['x'].size)

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

plt.figure(figsize=(10, 10))
plt.plot(phi, 'b--')
plt.plot(phi, 'b.')

plt.title('Convergence analysis', fontsize=title_font)
plt.xlabel('iteration', fontsize = title_font)
plt.ylabel('$\psi (\mathbf{p}, \mathbf{q})$', fontsize = title_font)
plt.tick_params(labelsize=13)

file_name = 'figs/convergence_LM_NNLS'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()

# %% [markdown]
# ### Estimated magnetization direction

# %%
print (inc_est,dec_est)
# Out:
# (-47.7106426834996, -111.64768830278784)

# %% [markdown]
# ### Comparison between observed data and predicted data

# %%
pred = fc.tfa_layer(data_set['x'],data_set['y'],data_set['z'],
                    xs,ys,zs,inc_gf,dec_gf,m_LM,inc_est,dec_est)

# %%
res = pred - data_set['tfa_20']

# %%
r_norm,r_mean,r_std = func.residual(data_set['tfa_20'],pred)

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(20,9), tight_layout=True)

ranges = saturation_factor*np.abs([data_set['tfa_20'].max(), 
                                   data_set['tfa_20'].min(),
                                   pred.max(), pred.min()]).max()

r_ranges = saturation_factor*np.abs([res.max(), res.min()]).max()


plt.subplot(1,4,1)
plt.tricontourf(data_set['y'], data_set['x'], data_set['tfa_20'], 20, cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (Obs) ', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=11)

plt.subplot(1,4,2)
plt.tricontourf(data_set['y'],data_set['x'], pred, 20, cmap='viridis',  vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (Layer)', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=11)

plt.subplot(1,4,3)
plt.tricontourf(data_set['y'],data_set['x'], res, 20, cmap='viridis',  vmin=-r_ranges, vmax=r_ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Residual map', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=11)


plt.subplot(1,4,4)
plt.xlabel('$\mu$ = %.3f | $\sigma$ = %.3f nT' % (r_mean, r_std),
           fontsize = bottom_font)
nbins = int((np.max(r_norm - np.min(r_norm))))
plt.hist(r_norm,bins=nbins,normed=True)
plt.ylim(0.,1.)
plt.xlim(-10., 10.)
plt.title('Normalized Histogram',fontsize=title_font)

file_name = 'figs/real_data_fitting_LM_NNLS'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()

# %% [markdown]
# ### Estimated magnetic moment within the layer

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

ranges = saturation_factor*np.abs([m_LM.max(), m_LM.min()]).max()

plt.tricontourf(ys,xs,m_LM,20,cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('$A.m^2$')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('Magnetic moment (layer)', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=13)

file_name = 'figs/magnetic_moment_positive_LM_NNLS'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')

plt.show()

# %% [markdown]
# ### Reduction to the pole

# %%
G_rtp = fc.sensitivity_mag(data_set['x'],data_set['y'],data_set['z'],
                       xs,ys,zs,90.,0.,90.,0.)

# %%
tfa_rtp = np.dot(G_rtp,m_LM)

# %% [markdown]
# #### Visualization of a reduction to the pole

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

ranges = saturation_factor*np.abs([tfa_rtp.max(), tfa_rtp.min()]).max()

plt.tricontourf(data_set['y'], data_set['x'], tfa_rtp, 20, cmap='viridis',vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0).set_label('nT')
plt.xlabel('y (m)', fontsize = title_font)
plt.ylabel('x (m)', fontsize = title_font)
plt.title('TFA (RTP)', fontsize=title_font)
plt.xlim(data_set['y'].min(),data_set['y'].max())
plt.ylim(data_set['x'].min(),data_set['x'].max())
plt.tick_params(labelsize=13)


file_name = 'figs/RTP_real_data_LM_NNLS'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')


plt.show()
