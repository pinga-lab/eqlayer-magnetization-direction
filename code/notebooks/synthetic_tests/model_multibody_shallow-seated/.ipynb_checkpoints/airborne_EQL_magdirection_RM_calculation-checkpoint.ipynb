# %% [markdown]
# # Equivalent layer technique for estimating total magnetization direction using

# %% [markdown]
# #### Importing libraries

# %%
% matplotlib inline

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime
import timeit
import string as st
from scipy.optimize import nnls
from fatiando.gridder import regular
from fatiando.utils import ang2vec, vec2ang
from fatiando.mesher import Sphere, PointGrid,Prism
from fatiando.gravmag import sphere,prism
from fatiando.constants import CM, T2NT, G, SI2MGAL
# Out:
# /home/vanderlei/Documents/fatiando/fatiando/vis/mpl.py:70: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
notebook_name = 'airborne_EQL_magdirection_RM_calculation.ipynb'

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../../../mypackage'
sys.path.append(dir_modules)

# %%
import auxiliary_functions as fc

# %% [markdown]
# #### Loading properties of the model

# %%
with open('data/model_multi.pickle') as f:
        model_multi = pickle.load(f)

# %% [markdown]
# #### Loading properties grid

# %%
with open('data/airborne_survey.pickle') as f:
        airborne = pickle.load(f)

# %% [markdown]
# #### Loading data

# %%
with open('data/data_set.pickle') as f:
        data = pickle.load(f)

# %% [markdown]
# #### Open a dictionary

# %%
result_RM_airb = dict()

# %% [markdown]
# ### Saving files

# %%
saved_files = []

# %% [markdown]
# ## Observation area

# %%
print 'Area limits: \n x_max = %.1f m \n x_min = %.1f m \n y_max = %.1f m \n y_min = %.1f m' % (airborne['area'][1], 
                                                                                                airborne['area'][0],
                                                                                                airborne['area'][3],
                                                                                                airborne['area'][2])
# Out:
# Area limits:
#  x_max = 5500.0 m
#  x_min = -6500.0 m
#  y_max = 6500.0 m
#  y_min = -5500.0 m

# %% [markdown]
# ### airborne survey information

# %%
print 'Shape : (%.0f,%.0f)'% airborne['shape'] 
print 'Number of data: %.1f' % airborne['N']
print 'dx: %.1f m' % airborne['dx']
print 'dy: %.1f m ' % airborne['dy']
# Out:
# Shape : (49,25)
# Number of data: 1225.0
# dx: 250.0 m
# dy: 500.0 m

# %% [markdown]
# ## Properties of the model

# %% [markdown]
# ### Main field

# %%
inc_gf,dec_gf = model_multi['main_field']

# %%
print'Main field inclination: %.1f degree' % inc_gf
print'Main field declination: %.1f degree' % dec_gf
# Out:
# Main field inclination: -40.0 degree
# Main field declination: -22.0 degree

# %% [markdown]
# ### Magnetization direction

# %%
print 'Inclination: %.1f degree' % model_multi['inc_R']
print 'Declination: %.1f degree' % model_multi['dec_R']
# Out:
# Inclination: -25.0 degree
# Declination: 30.0 degree

# %%
inc_R,dec_R = model_multi['inc_R'],model_multi['dec_R']

# %% [markdown]
# ## Generating the layer with my function

# %%
h = 1150.

# %% [markdown]
# #### Generating a layer

# %%
shape_layer = (airborne['shape'][0],airborne['shape'][1])

# %%
xs,ys,zs = regular(airborne['area'],shape_layer,h)

# %% [markdown]
# ### Levenberg-Marquardt with NNLS for positive magnetic moments

# %%
i_pos = 1250

# %%
it_max = 30

# %%
it_marq = 15

# %%
lamb = 10.
dlamb = 100.

# %%
eps_e = 1e-4
eps_i = 1e-4

# %%
mu_list = [1e2,1e3,1e4,1e5,3.5*1e5,5*1e5,1e6,5*1e6]

# %%
mu_norm = []
norm_r = []
norm_m = []
m_est = []
incl_est = []
decl_est = []
phi_list = []
for i in mu_list:
    m_LM,inc_est,dec_est,phi,imax,pest,incs,decs = fc.LM_NNLS(
        data['tfa_obs_RM_airb'],airborne['x'],airborne['y'],
        airborne['z'],xs,ys,zs,inc_gf,dec_gf,-10.,-10.,lamb,dlamb,i_pos,it_max,
        it_marq,eps_e,eps_i,i)
    G = fc.sensitivity_mag(airborne['x'],airborne['y'],airborne['z'],
                       xs,ys,zs,inc_gf,dec_gf,inc_est,dec_est)
    tfpred = np.dot(G,m_LM)
    r = data['tfa_obs_RM_airb'] - tfpred 
    
    norm_r.append(np.sqrt(np.sum(r*r)))
    norm_m.append(np.sqrt(np.sum(m_LM*m_LM)))
    m_est.append(m_LM)
    incl_est.append(inc_est)
    decl_est.append(dec_est)
    phi_list.append(phi)
# Out:
# i = 0
# -15.789750267576052 -7.798072114569725
# 0.12274334555655109
# i = 1
# -19.717509936535112 -5.250655626636244
# 0.08836086440872964
# i = 2
# -22.581686247789943 -2.607517572124029
# 0.06644505641160585
# i = 3
# -24.767529214887553 -0.020588309097486726
# 0.05163112922672421
# i = 4
# -26.501051758158987 2.5711215332393507
# 0.04387809109931861
# i = 5
# -27.87293735262645 5.228788876728081
# 0.04046270568517445
# i = 6
# -28.923135048955736 7.939125368159975
# 0.03928843287790247
# i = 7
# -29.68408697019039 10.58060376767783
# 0.03709488980534159
# i = 8
# -30.200939038733917 13.049704449415241
# 0.033559122246989204
# i = 9
# -30.50336108385887 15.31362993463001
# 0.02975647977738874
# i = 10
# -30.64268787729382 17.333019174270905
# 0.025356232066933725
# i = 11
# -30.669725041299476 19.092509449395237
# 0.020704998351058032
# i = 12
# -30.629440235034334 20.604102371894946
# 0.016368297429439987
# i = 13
# -30.553891377495535 21.878773145594998
# 0.012351771311037976
# i = 14
# -30.462189715536095 22.94199847959117
# 0.009024168502787573
# i = 15
# -30.36528653777629 23.824534015080093
# 0.006469419697925139
# i = 16
# -30.274416360981345 24.562718051650407
# 0.0046551248656499416
# i = 17
# -30.194745998442045 25.181734551585578
# 0.003334535796298128
# i = 18
# -30.125596163727128 25.709719788116494
# 0.0024579708271067996
# i = 19
# -30.062896345111138 26.18013176638944
# 0.001971459901039376
# i = 20
# -30.006077654489548 26.601775290435818
# 0.0015973536531963995
# i = 21
# -29.954090299861615 26.98891298437342
# 0.001354892151462022
# i = 22
# -29.908273321002742 27.341472908227914
# 0.0011271187846203614
# i = 23
# -29.866721716026913 27.663640946782028
# 0.0009448739249090835
# i = 24
# -29.827435783377233 27.96174512676229
# 0.000813335370508158
# i = 25
# -29.78913687014733 28.24039299752922
# 0.0007153081001656425
# i = 26
# -29.750090388024994 28.502939821044215
# 0.0006411996176917135
# i = 27
# 0.022685906012032495
# i = 10
# -30.39587283413497 18.685942865223097
# 0.018137650291426898
# i = 11
# -30.3890774778354 20.29972328832641
# 0.013922955387430295
# i = 12
# -30.333521440280567 21.6466973350204
# 0.010264198145498154
# i = 13
# -30.254917515473476 22.756733843402174
# 0.007303703756997553
# i = 14
# -30.172451065951122 23.666279379428637
# 0.005078154250476773
# i = 15
# -30.095266661657785 24.41867530440993
# 0.003562090215607269
# i = 16
# -30.025839092132973 25.05679420374391
# 0.0026070985323455777
# i = 17
# -29.964305178527624 25.610791798946746
# 0.001989054419876129
# i = 18
# -29.910435116923995 26.097040925558414
# 0.0015454254939793845
# i = 19
# -29.864207113752286 26.526995739811017
# 0.0012146473598959719
# i = 20
# -29.823901554560518 26.91912087588395
# 0.0010136249022337112
# i = 21
# -29.78872461786909 27.279240832819163
# 0.0008568862207265999
# i = 22
# -29.758434949648425 27.611332116618332
# 0.0007295258483212165
# i = 23
# -29.73284454399948 27.918217725905546
# 0.0006230858183785241
# i = 24
# -29.70843469308396 28.204623333245117
# 0.0005445313927807867
# i = 25
# -29.683022185509156 28.47407138100896
# 0.00048485201194460836
# i = 26
# -29.65649767564026 28.729232086241964
# 0.0004375874657703932
# i = 27
# -29.628521974703137 28.971240647369246
# 0.0003966357902855866
# i = 28
# -29.599075914944777 29.200371866334844
# 0.00035863527459254195
# i = 29
# -29.568545356853544 29.41757682089756
# 0.000325079445078062
# i = 30
# -29.537175725705183 29.623539074201325
# 0.00029491571481634124
# i = 31
# -29.504887709983908 29.81915915684666
# 0.00026870463866525835
# i = 32
# -29.471385650131623 30.005514147899152
# 0.00024674851878414436
# i = 33
# -29.436861918468974 30.183020825452143
# 0.0002266791680803322
# i = 34
# -29.401491501512556 30.35225177992657
# 0.00020871679569247026
# i = 35
# -29.365361090936577 30.513983865782432
# 0.0001932066673517575
# i = 36
# -29.328570830387346 30.66840231785537
# 0.00017867861884915024
# i = 37
# -29.29065467428477 30.814281230235032
# 0.00016284963826924707
# i = 38
# -29.25144410248611 30.95245105479783
# 0.0001496906417056925
# i = 39
# -29.210893438640234 31.08347442512485
# 0.00013836497452344814
# i = 40
# -29.169297018315046 31.207902310314246
# 0.0001283335967475036
# i = 41
# -29.126883312440754 31.32620763157931
# 0.00011937942520629156
# i = 42
# -29.08385407617756 31.438802071642815
# 0.00011131233771583508
# i = 43
# -29.040531164931085 31.546522097407333
# 0.00010452440946793314
# i = 44
# -28.996876876455694 31.64993015575922
# 0.0
# i = 0
# -16.206423299566556 -7.529940642566711
# 0.10216909439318662
# i = 1
# -20.28794023438698 -4.544455042614074
# 0.06902067017240726
# i = 2
# -23.306313779420222 -1.342331713737147
# 0.05452456519074319
# i = 3
# -25.585541283593717 1.9011759658398486
# 0.04501594866035151
# i = 4
# -27.30194897515355 5.171829357950327
# 0.03967108307426168
# i = 5
# -28.552282518666868 8.413477758691467
# 0.03649525044603203
# i = 6
# -29.403270952790738 11.496824039823656
# 0.032961627209354305
# i = 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-d7eb6c802537> in <module>()
#      10         data['tfa_obs_RM_airb'],airborne['x'],airborne['y'],
#      11         airborne['z'],xs,ys,zs,inc_gf,dec_gf,-10.,-10.,lamb,dlamb,i_pos,it_max,
# ---> 12         it_marq,eps_e,eps_i,i)
#      13     G = fc.sensitivity_mag(airborne['x'],airborne['y'],airborne['z'],
#      14                        xs,ys,zs,inc_gf,dec_gf,inc_est,dec_est)
#
# /home/vanderlei/Documents/eqlayer-magnetization-direction/code/mypackage/auxiliary_functions.pyc in LM_NNLS(dobs, x, y, z, xs, ys, zs, sinc, sdec, inc0, dec0, lamb, dlamb, imax, itext, itmarq, eps_e, eps_i, mu)
#     424         f0 = np.trace(np.dot(G_mag.T,G_mag))/M
#     425         GI = np.vstack([G_mag,mu*f0*I])
# --> 426         p0,_ = nnls(GI,do)
#     427         tf_ext = tfa_layer(x,y,z,xs,ys,zs,sinc,sdec,p0,inc0,dec0)
#     428         r_ext = dobs - tf_ext
#
# /home/vanderlei/anaconda3/envs/fatiando2/lib/python2.7/site-packages/scipy/optimize/nnls.pyc in nnls(A, b, maxiter)
#      59     index = zeros((n,), dtype=int)
#      60
# ---> 61     x, rnorm, mode = _nnls.nnls(A, m, n, b, w, zz, index, maxiter)
#      62     if mode != 1:
#      63         raise RuntimeError("too many iterations")
#
# KeyboardInterrupt:

# %% [markdown]
# ## L-curve visualization

# %%
title_font = 20
bottom_font = 18
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(9,9), tight_layout=True)

plt.figure(figsize=(10, 10))
plt.loglog(norm_r,norm_m, 'b-')
plt.loglog(norm_r,norm_m, 'bo')
plt.title('L-curve', fontsize=title_font)
plt.xlabel('r_norm', fontsize = title_font)
plt.ylabel('m_norm', fontsize = title_font)
plt.tick_params(axis='both', which='major', labelsize=15)

file_name = 'figs/airborne/Lcurve_RM'
plt.savefig(file_name+'.png',dpi=300)
saved_files.append(file_name+'.png')

plt.savefig(file_name+'.eps',dpi=300)
saved_files.append(file_name+'.eps')


plt.show()

# %% [markdown]
# ### Results

# %%
result_RM_airb['magnetic_moment'] = m_est
result_RM_airb['inc_est'] = incl_est
result_RM_airb['dec_est'] = decl_est
result_RM_airb['layer_depth'] = h
result_RM_airb['reg_parameter'] = mu_list
result_RM_airb['phi'] = phi_list

# %% [markdown]
# ### Generating .pickle file

# %%
now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
result_RM_airb['metadata'] = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)

# %%
file_name = 'data/result_RM_airb.pickle'
with open(file_name, 'w') as f:
    pickle.dump(result_RM_airb, f)
    
saved_files.append(file_name)

# %% [markdown]
# ### Saved files

# %%
with open('reports/report_%s.md' % notebook_name[:st.index(notebook_name, '.')], 'w') as q:
    q.write('# Saved files \n')
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
    q.write('\n\n'+header+'\n\n')
    for i, sf in enumerate(saved_files):
        print '%d  %s' % (i+1,sf)
        q.write('*  `%s` \n' % (sf))
